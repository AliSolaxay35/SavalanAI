# %%
import torch
import numpy as np

# %%
data = [[1,2],[3,4],[5,6]]

# %%
data
# Out:
# [[1, 2], [3, 4], [5, 6]]

# %%
type(data)
# Out:
# list

# %%
np_data = np.array(data)

# %%
np_data
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
torch_data = torch.tensor(data)

# %%
torch_data
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
tensor = torch.from_numpy(np_data)

# %%
tensor
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
if torch.cuda.is_available():
  tensor = tensor.to("cuda")
  print(f"stored in : {tensor.device}")
else:
  print("oops!")
# Out:
# oops!

# %%
tensor * tensor
# Out:
# tensor([[ 1,  4],
#         [ 9, 16],
#         [25, 36]])

# %%
tensor **28
# Out:
# tensor([[                   1,            268435456],
#         [      22876792454961,    72057594037927936],
#         [  359414837200037393, -1823562080465190912]])

# %%
tensor.mul(3)
# Out:
# tensor([[ 3,  6],
#         [ 9, 12],
#         [15, 18]])

# %%
torch.cat([tensor, tensor, tensor], dim=1)
# Out:
# tensor([[1, 2, 1, 2, 1, 2],
#         [3, 4, 3, 4, 3, 4],
#         [5, 6, 5, 6, 5, 6]])
